# %% [markdown]
# # Running Stan on JuliaBox

# %% [markdown]
# ## Introduction to Stan and Stan.jl

# %% [markdown]
# Stan ( http://mc-stan.org ) is one of several tools available to perform Bayesian sampling. Statistical inference based on Stan's result (the posterior samples in 1 or more chains) are typically done in R, Python or Matlab. Stan.jl uses Stan as an external program and simplifies running Stan models and subsequent inference, all from within Julia, thus providing a fourth 'interface' to Stan.
#
# Stan is written in C++ but still attractive to Julia users because it is a very good tool for users interested in Bayesian models that can be efficiently sampled with Stan. It is also supported by a very capable team and community willing to help out with modeling and installation issues. Reasons enough for the existance of Stan.jl.
#
# JuliaBox contributes another major benefit in that it removes the burden of installing Stan from the end users. The user still has a 'private' permanent file system to store Julia scripts that include the Stan model and available data. All accessible through a user friendly Notebook interface that includes several options for the graphical display of results!
#
# Finally, pushing Stan's envelope can require knowledge of C++, C++ templates, the C++ Boost libraries, R, the Stan modeling language, and its extensions (e.g. functions). This can be a daunting task. Stan.jl can't help here but Julia's ecosystem provides options entirely written in Julia, like Mamba.jl ( http://mambajl.readthedocs.org/en/latest/index.html ) and MCMC.jl ( http://mcmcjl.readthedocs.org/en/latest/ ) which, if access to lower level MCMC functionality is required, might be a better route. Using Stan.jl will pave the way to such a migration.

# %% [markdown]
# ## Getting started, some preliminaries ...

# %% [markdown]
# Running below cell is occasionally useful to make sure all JuliaBox packages are up to date. Removing package "JuMP" is not absolutely necessary but prevents a couple of warnings when plotting the results with Gadfly.

# %%
Pkg.update()
Pkg.rm("JuMP")
# Out:
# INFO: Updating METADATA...
# INFO: Updating ELM...
# INFO: Updating ANN...
# INFO: Updating Stan...
# INFO: Updating Jags...
# INFO: Updating Permutations...
# INFO: Updating MCMCExampleRepository...
# INFO: Computing changes...
# INFO: No packages to install, update or remove
# INFO: Nothing to be done

# %% [markdown]
# Stan.jl relies on Mamba.jl's very broad collection of functions for posterior inference and display after the MCMC sampling has been performed by Stan. Compat.jl is used for compatibility with newer versions of Julia.

# %%
using Mamba, Stan, Compat;

# %% [markdown]
# In this example we'll use one of several examples that are included in Stan.jl, i.e. estimating the distribution of the success probability (theta) based on 4 sets of 10 observed outcomes.
#
# I like to control where I store intermediate and result files. In this case I 'borrow' the Bernoulli directory inside Stan.jl.

# %%
old = pwd()
ProjDir = Pkg.dir("Stan", "Examples", "Bernoulli")
cd(ProjDir)

# %% [markdown]
# ## A Stan model and its data

# %% [markdown]
# Define a simple Stan model. On JuliaBox it is best to define the model inline, but it could also be stored in an external file and uploaded to JuliaBox.

# %%
bernoullimodel = "
data { 
  int<lower=0> N; 
  int<lower=0,upper=1> y[N];
} 
parameters {
  real<lower=0,upper=1> theta;
} 
model {
  theta ~ beta(1,1);
    y ~ bernoulli(theta);
}
";

# %% [markdown]
# Define the observed data, in this case the number of observations in the 4 experiments and the outcomes of these observations. This is an array of dictionaries. By default Stan will run 4 chains and in this setup each chain is assigned a dictionary with the results of 1 experiment. If that is an acceptable way to analyze these results depends on the purpose of the 4 experiments. It's used here purely as an illustration, e.g. one could increase the probability of success in one of the experiment by updating the y vector. This will show up in the overall value of theta below and in the plots for that chain.

# %%
bernoullidata = [
  @Compat.Dict("N" => 10, "y" => [0, 1, 0, 1, 0, 0, 0, 0, 0, 1]),
  @Compat.Dict("N" => 10, "y" => [0, 1, 0, 0, 0, 0, 1, 0, 0, 1]),
  @Compat.Dict("N" => 10, "y" => [0, 0, 0, 0, 0, 0, 1, 0, 1, 1]),
  @Compat.Dict("N" => 10, "y" => [0, 0, 0, 1, 1, 0, 0, 1, 0, 1])
];

# %% [markdown]
# ## Setting up a Stanmodel and sampling from the model

# %% [markdown]
# Stanmodel() and stan() are the main functions provided by Stan.jl. For details on the arguments of these functions see the CmdStan documentation and the README in Stan.jl ( https://github.com/goedman/Stan.jl )

# %%
stanmodel = Stanmodel(update=1200, thin=2, name="bernoulli", model=bernoullimodel);
# Out:
# File /Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli.stan will be updated.

# %%
sim1 = stan(stanmodel, bernoullidata, ProjDir, diagnostics=false);
# Out:
# --- Translating Stan model to C++ code ---
# bin/stanc /Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli.stan --o=/Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli.cpp --no_main
# Model name=bernoulli_model
# Input file=/Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli.stan
# Output file=/Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli.cpp
#
# --- Linking C++ model ---
# clang++ -DBOOST_RESULT_OF_USE_TR1 -DBOOST_NO_DECLTYPE -DBOOST_DISABLE_ASSERTS -I src -I stan/src -isystem stan/lib/eigen_3.2.2 -isystem stan/lib/boost_1.54.0 -Wall -pipe -DEIGEN_NO_DEBUG -Wno-unused-function -ftemplate-depth-256    -O3 -o /Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli src/cmdstan/main.cpp -include /Users/rob/.julia/v0.3/Stan/Examples/Bernoulli/tmp/bernoulli.cpp -Lbin -lstan
# Inference for Stan model: bernoulli_model
# 4 chains: each with iter=(1200,1200,1200,1200); warmup=(0,0,0,0); thin=(1,1,1,1); 4800 iterations saved.
#
# Warmup took (0.0089, 0.0085, 0.015, 0.0097) seconds, 0.042 seconds total
# Sampling took (0.026, 0.027, 0.022, 0.028) seconds, 0.10 seconds total
#
#                 Mean     MCSE  StdDev    5%   50%   95%  N_Eff  N_Eff/s    R_hat
# lp__            -8.3  7.9e-02    0.86   -10  -8.2  -7.6    119     1164  1.0e+00
# accept_stat__   0.92  1.7e-03    0.12  0.68  0.97   1.0   4800    46902  1.0e+00
# stepsize__      1.00  5.4e-02   0.077  0.91  1.00   1.1    2.0       20  2.7e+13
# treedepth__      1.7  1.2e-02    0.56   1.0   2.0   3.0   2366    23118  1.0e+00
# n_leapfrog__     2.6  1.7e-01     1.5   1.0   3.0   7.0     74      722  1.0e+00
# n_divergent__   0.00  0.0e+00    0.00  0.00  0.00  0.00   4800    46902      nan
# theta           0.36  2.4e-02    0.14  0.13  0.35  0.60     35      347  1.0e+00
#
# Samples were drawn using hmc with nuts.
# For each parameter, N_Eff is a crude measure of effective sample size,
# and R_hat is the potential scale reduction factor on split chains (at
# convergence, R_hat=1).

# %% [markdown]
# From above summary you can see that by default Stan.jl runs 4 chains. Stan will not perform any thinning, this is done later on in fact as we defined a thinning factor of 2 in the Stanmodel() call.
#
# Notice that if we were to run the simulation again the Stan Model would not be compiled unless the model has been changed.

# %% [markdown]
# ## Posterior analysis

# %% [markdown]
# Stan records 6 variables by default augmented by model specific variables (only theta in this example). Not all of these are suitable for posterior inference. In this example we'll only perform posterior analysis on "theta", "lp__" and "accept_stat__".
#
# In some cases Stan might record 10s, 100s even 1000s of model specific variables. In those cases a variable like 'posterior' can be used to constrain the number of variables used in posterior analysis.

# %%
posterior = ["theta", "lp__", "accept_stat__"];

# %% [markdown]
# Apply the subset 'posterior' before calling describe().

# %%
sim = sim1[:, posterior, :]
describe(sim)
# Out:
# Iterations = 1:2399
# Thinning interval = 2
# Chains = 1,2,3,4
# Samples per chain = 1200
# Empirical Posterior Estimates:
# 4x6 Array{Any,2}
# :
#  ""                 "Mean"    "SD"      "Naive SE"   "MCSE"         "ESS"
#  "lp__"           -8.33453   0.859307  0.012403     0.0215571   2761.71
#  "accept_stat__"   0.924739  0.115957  0.00167369   0.00106181  4800.0
#  "theta"           0.356503  0.140498  0.00202792   0.00374366  2600.13
#
# Quantiles:
# 4x6 Array{Any,2}
# :
#  ""                  "2.5%"     "25.0%"    "50.0%"    "75.0%"    "97.5%"
#  "lp__"           -10.7715    -8.53415   -8.15059   -7.74009   -7.63948
#  "accept_stat__"    0.578272   0.902672   0.973005   1.0        1.0
#  "theta"            0.097483   0.254159   0.353907   0.451617   0.651197

# %% [markdown]
# Mamba.jl provides a range of function to diagnose and analyze the simulation result, e.g. gelmandiag() is shown below. See the Mamba documentation ( http://mambajl.readthedocs.org/en/latest/index.html ) or the Bernoulli example in Stan.jl for other options.

# %%
gelmandiag(sim, mpsrf=true, transform=true)
# Out:
# 5x3 Array{Any,2}
# :
#  ""                "PSRF"     "97.5%"
#  "lp__"           1.0343     1.09753
#  "accept_stat__"  1.07489    1.12668
#  "theta"          1.04476    1.13163
#  "Multivariate"   1.1945   NaN

# %% [markdown]
# ## Plot the results

# %%
p = plot(sim, [:trace, :mean, :density, :autocor], legend=true);

# %%
draw(p, ncol=4)
# Out:
# SVG(203.2,203.2,IOBuffer(data=Uint8[...], readable=true, writable=true, seekable=true, append=false, size=475798, maxsize=Inf, ptr=475799, mark=-1),nothing,"fig-611dbacdd7fd49f881b6003e8fd8bcb5",0,[],[Property{StrokePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing],[ClipPrimitive([Point(Measure{MeasureNil,MeasureNil}(72.21833333333333,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(12.611666666666665,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(96.6,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(12.611666666666665,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(96.6,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(46.42833333333332,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(72.21833333333333,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(46.42833333333332,MeasureNil(),MeasureNil(),0.0,0.0))])=>"fig-611dbacdd7fd49f881b6003e8fd8bcb5-element-459",ClipPrimitive([Point(Measure{MeasureNil,MeasureNil}(172.14499999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(80.34499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(188.7858333333333,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(80.34499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(188.7858333333333,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(118.18166666666664,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(172.14499999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(118.18166666666664,MeasureNil(),MeasureNil(),0.0,0.0))])=>"fig-611dbacdd7fd49f881b6003e8fd8bcb5-element-199",ClipPrimitive([Point(Measure{MeasureNil,MeasureNil}(18.631666666666664,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(80.34499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(45.8,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(80.34499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(45.8,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(114.16166666666663,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(18.631666666666664,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(114.16166666666663,MeasureNil(),MeasureNil(),0.0,0.0))])=>"fig-611dbacdd7fd49f881b6003e8fd8bcb5-element-325",ClipPrimitive([Point(Measure{MeasureNil,MeasureNil}(117.88499999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(148.07833333333332,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(147.39999999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(148.07833333333332,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(147.39999999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(185.91499999999996,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(117.88499999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(185.91499999999996,MeasureNil(),MeasureNil(),0.0,0.0))])=>"fig-611dbacdd7fd49f881b6003e8fd8bcb5-element-56",ClipPrimitive([Point(Measure{MeasureNil,MeasureNil}(119.55833333333331,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(80.34499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(147.39999999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(80.34499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(147.39999999999998,MeasureNil(),MeasureNil(),0.0,0.0),Measure{MeasureNil,MeasureNil}(116.83499999999998,MeasureNil(),MeasureNil(),0.0,0.0)),Point(Measure{MeasureNil,MeasureNil}(119.55833333333331,MeasureNil(),Mea ...

# %% [markdown]
# ## Housekeeping ...

# %% [markdown]
# Intermediate results are all in the 'tmp' directory. Results that you might want to keep around are left in the current working directory (ProjDir as defined above).

# %%
;ls
# Out:
# bernoulli-summaryplot-1.pdf
# bernoulli-summaryplot-1.svg
# bernoulli.jl
# bernoulli_diagnose.jl
# bernoulli_optimize.jl
# tmp

# %% [markdown]
# What's in the 'tmp' directory?

# %%
;ls tmp
# Out:
# bernoulli
# bernoulli.cpp
# bernoulli.stan
# bernoulli_1.data.R
# bernoulli_2.data.R
# bernoulli_3.data.R
# bernoulli_4.data.R
# bernoulli_build.log
# bernoulli_run.log
# bernoulli_samples_1.csv
# bernoulli_samples_2.csv
# bernoulli_samples_3.csv
# bernoulli_samples_4.csv

# %% [markdown]
# ##### You can remove the 'tmp' directory. If you do this, future simulations will require redefinition of the Stanmodel() and recompilation when calling stan()!

# %%
#isdir("tmp") && rm("tmp", recursive=true)
